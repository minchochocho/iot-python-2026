# %% [markdown]
# ## 주피터 노트북 시작
#
# - 마크다운 셸은 일반 md 파일에서 작성하는 것과 동일
# - Ctrl + Enter
# - [구글](https://google.co.kr) 과 같이 웹사이트 링크 사용가능
#
# - 주피터 노트북의 경로는 해당위치부터 시작
# - ![이미지](../image-1.png)

# %%
print('Hello Jupyter')
# Out:
# Hello Jupyter

# %%
num = int(input('정수 입력 > '))

# %%
print(num)
# Out:
# 10

# %%
num
# Out:
# 10

# %%
# print() 함수와 변수명만 적는게 모두 출력
num
num + 10
num * 10
# Out:
# 100

# %% [markdown]
# - print() 함수를 사용하지 않으면 가장 마지막의 변수만 출력
# - 모두 출력하고자 하면 모드 print() 함수를 쓸 것

# %%
print(num)
print(num+100)
print(num* 100)
# Out:
# 10
# 110
# 1000
